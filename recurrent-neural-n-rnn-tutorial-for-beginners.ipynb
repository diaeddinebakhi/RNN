# %% [markdown]
# ![RNN.gif](attachment:4692c423-aa44-4a4e-83c0-77d12414c333.gif)
#
# <center><h1 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">Introduction 📖 </h1></center>
# <p style = "color:black;font-family:Segoe Print;font-weight:bold">The data (last updated 11/10/2017) is presented in CSV format as follows: Date, Open, High, Low, Close, Volume, OpenInt.</p>
#
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > What are we going to do in this notebook? </p>
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold">First, we look at our very short model. Later, we'll talk about what RNN is. We will look at how RNN works and we will support this with visuals. We will look at where RNN is used. In short, we will try to understand the things we have stated in the content section below as logic without going into the mathematics of the work. </p>
#
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > So, let's get started. </p>
#
# <h2 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">Content :</h2>
#
# <ul>
#     <li style = "color:gray;font-size:16px"> <a href = "#1" style = "color:black;font-family:Segoe Print;font-weight:bold"> Load and Check Data 🗸 </a> </li>
#         <li style = "color:gray;font-size:16px"> <a href = "#2" style = "color:black;font-family:Segoe Print;font-weight:bold"> Recurrent Neural Networks (RNN) 📚 </a>
#             <ul>
#                 <li style = "color:black;font-size:16px" ><a href = "#3" style = "color:darkred;font-family:Segoe Print;font-weight:bold"> What is this RNN ❓ </a></li>
#                 <li style = "color:black;font-size:16px" ><a href = "#4" style = "color:darkred;font-family:Segoe Print;font-weight:bold"> We said RNN will remember. so how does that happen? </a></li></ul>
#          <li style = "color:gray;font-size:16px" ><a href = "#5" style = "color:black;font-family:Segoe Print;font-weight:bold"> Why Recurrent Neural Networks ❓ </a> </li>
#                       <li style = "color:gray;font-size:16px" ><a href = "#6" style = "color:black;font-family:Segoe Print;font-weight:bold"> What are the application areas of RNN ❓ </a> </li>
#                                    <li style = "color:gray;font-size:16px" ><a href = "#7" style = "color:black;font-family:Segoe Print;font-weight:bold" > What are the types of RNN ❓ </a> <ul>
#                                        <li style = "color:gray;font-size:16px" ><a href = "#8" style = "color:black;font-family:Segoe Print;font-weight:bold" > One to One ⁉️ </a></li>
#                                         <li style = "color:gray;font-size:16px" ><a href = "#9" style = "color:black;font-family:Segoe Print;font-weight:bold" > One to Many ⁉️ </a></li>
#                                         <li style = "color:gray;font-size:16px" ><a href = "#10" style = "color:black;font-family:Segoe Print;font-weight:bold" > Many to One ⁉️ </a></li>
#                                         <li style = "color:gray;font-size:16px" ><a href = "#11" style = "color:black;font-family:Segoe Print;font-weight:bold" > Many to Many ⁉️ </a></li>
#                                        </ul></li>
#     <li  style = "color:gray;font-size:16px" > <a href = "#12" style = "color:black;font-family:Segoe Print;font-weight:bold" > Data Preprocessing ❔ </a>
#         <ul>
#             <li style = "color:gray;font-size:16px" ><a href = "#13" style = "color:black;font-family:Segoe Print;font-weight:bold" >  Split the data as train and test ❓ </a> </li>
#             <li style = "color:gray;font-size:16px" ><a href = "#14" style = "color:black;font-family:Segoe Print;font-weight:bold" >  Normalize Data ❓ </a>
#                 <ul>
#                     <li style = "color:gray;font-size:16px" ><a href = "#15" style = "color:darkblue;font-family:Segoe Print;font-weight:bold" >   Why do we normalize data? </a></li>
#                 </ul>
#             </li>
#             <li style = "color:gray;font-size:16px" ><a href = "#16" style = "color:black;font-family:Segoe Print;font-weight:bold" >  X_train - y_train ❓ </a>
#                 <ul>
#                     <li style = "color:gray;font-size:16px" ><a href = "#17" style = "color:darkblue;font-family:Segoe Print;font-weight:bold" >   What is the steps logic? </a></li>
#                 </ul>
#             </li>
#             <li style = "color:gray;font-size:16px" ><a href = "#18" style = "color:black;font-family:Segoe Print;font-weight:bold" >  Reshape ❓ </a>
#                 <ul>
#                     <li style = "color:gray;font-size:16px" ><a href = "#19" style = "color:darkblue;font-family:Segoe Print;font-weight:bold" >   why do we reshape ? </a></li>
#                 </ul>
#             </li>
#         </ul>
#     </li>
#             <li style = "color:gray;font-size:16px" ><a href = "#20" style = "color:black;font-family:Segoe Print;font-weight:bold" > Implementing with Keras ❔ </a> <ul>
#           <li style = "color:gray;font-size:16px" ><a href = "#21" style = "color:black;font-family:Segoe Print;font-weight:bold" > Create Model ❓ </a></li>
#                                         <li style = "color:gray;font-size:16px" ><a href = "#22" style = "color:black;font-family:Segoe Print;font-weight:bold" > Compile Model ❓ </a></li>
#                                         <li style = "color:gray;font-size:16px" ><a href = "#23" style = "color:black;font-family:Segoe Print;font-weight:bold" > Epochs and Batch Size ❓ </a></li>
#                                         <li style = "color:gray;font-size:16px" ><a href = "#24" style = "color:black;font-family:Segoe Print;font-weight:bold" > Fit the model ❓ </a></li>
#                                        </ul></li>
#                           <li style = "color:black;font-size:16px" ><a href = "#25" style = "color:black;font-family:Segoe Print;font-weight:bold"> Predict ❓ </a></li>
#                              <li style = "color:black;font-size:16px" ><a href = "#26" style = "color:black;font-family:Segoe Print;font-weight:bold"> Evaluate the model ❔ </a></li>
#        <li style = "color:black;font-size:16px" ><a href = "#27" style = "color:darkred;font-family:Segoe Print;font-weight:bold"> CONCLUSION </a></li>
#        </ul>
#     </li>
# </ul>

# %% [markdown]
# <h2 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">Import Libraries 🔖 </h2>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ufi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vfl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sohu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rdcm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/virt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hylb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/skt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/asix.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mac.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gut.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ngs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vpg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ibtx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/coda.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/evlmc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/crd-b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/matx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/htf-cl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sid.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pol.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hhyx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/orpn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cbb_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dvax.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ll.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vamo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/eslt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fhn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cccr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hbnc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/inn_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nhc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fax.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/xivh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/artw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/myok.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fcap.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wbir.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/iboc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bkt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/loma.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/plt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nulg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mtfb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/home.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/iae.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/live.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/w.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/spro.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tree.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nsa.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sti-ws-a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/prty.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bhacu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sdlp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/trv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/civbp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/huntw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bzm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/imgn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mlnx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bco.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/metc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cspi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/linc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cbfv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rdib.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vsar.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/stmp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sxe.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cvs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/amd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/thff.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wow.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pkbk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/slg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cvlt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sbt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vicl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mtb_.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nrim.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/o.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sfl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gnus.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/seac.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/abb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cpac.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/weys.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lngr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ren.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sov_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ffiu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/deck.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bqh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/blmt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rvsb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/atr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/asr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ffsg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ipar.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/srva.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rfi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/utmd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gnt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cytxw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rig.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nkg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/extn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mtge.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mlss.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wins.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/syke.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sfs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cyrn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kyo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/corr_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hbanp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pzn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sunw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fivn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pfin.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/epam.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/yld.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bsrr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vgm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/seas.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wyde.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/osur.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fate.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cybr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mnta.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/swp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/erf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wmk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/apti.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cris.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gbx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/an.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/snfca.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tvty.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pbb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/amsc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/banr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mbwm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/iqdg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tac.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/prph.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fusb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nvtr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/all_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cfcou.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/athm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hylv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/klac.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/zb_g.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/qtm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/plx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ssp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aemd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bte.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pmom.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ktovw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/eigi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/urgn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/evol.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dtus.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mpv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fnte.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/embh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/iht.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wsci.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vktx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wfc_t.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cmg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nesrw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pavmw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nsec.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dskew.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jpgb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fmhi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kffb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bokf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/acv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/eufl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pbr-a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fcfs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/le.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/epr_e.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cotv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/csbk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mzor.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cqh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/arc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kodk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rare.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/andau.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ubs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/llqd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/psc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dems.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rfdi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dri.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/xog.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rev.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fosl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/psa_w.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fllv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dezu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/indf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cara.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ship.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dhi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ttmi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mca.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pbbi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sf_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hbio.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cmre_d.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/htbk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nvro.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/landp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/payc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cvr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vcra.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/esl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hotr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wtfcm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/faln.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/intu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dbd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/usb_m.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fast.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sswa.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gs_i.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/amfw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fsac.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sndr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/crhm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jasn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hlf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cei.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nhi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ddr_k.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hsea.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/p.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/run.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cfbk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pgem.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/yesr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tal.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pot.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cxrx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/loan.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/irtc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/yelp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/son.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/scacw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mcs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/clls.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nws.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/acglo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/clsn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wbih.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aht_g.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rmniu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mpacw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sanw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ccih.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/met.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cthr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cyd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ago_f.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/acer.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gs_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jone.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cnat.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dlx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mei.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kins.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ssb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bios.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ovbc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nete.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pch.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/atlo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kap.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ambc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/coup.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/omi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cubn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gst_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/teso.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jof.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gim.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ldos.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/maa_i.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tgb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sswn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ino.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/h.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/skys.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dave.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ctmx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/abeow.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/haud.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bnj.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/drd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/save.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aset.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jcs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cee.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/amsf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gsm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fit.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/apog.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/uhs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cmo_e.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/acc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wvvip.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ric.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bhe.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ehth.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/blw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lsxma.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hygs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cui.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ncz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lfc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/unit.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/oxlcm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cgg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/snhni.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wtfcw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mosc-u.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/atv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pfn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mck.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/too.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sbfgp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/zayo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/oew.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/llit.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/menu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/c_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ibkco.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mdso.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bsf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vntv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fce-a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/airi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ryam.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/amg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/shld.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/btg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/arnc_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/trp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ptla.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lkq.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/terp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/scco.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/frsx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wsbf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/psdo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vbtx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rgc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vno_k.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/icl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wsfs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bwxt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ctic.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/csf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pnc_q.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bwl-a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/strt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/on.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vrts.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/htgx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/unt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/usrt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gthx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cj.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ewre.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/src_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wbiy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/usm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fti.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ipas.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ahh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mus.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jpin.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wsky.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gwb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wlkp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cbh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rxdx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/agm-a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/psti.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/flhk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mstr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nomd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pds.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/idev.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sbsi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ntrp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/crm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/asg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lmrkp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/acerw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ssnt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ibo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ctbb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/al.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fxep.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fdef.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ubp_g.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/derm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ffg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dvmt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ival.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/asa.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bctf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wwd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/anh_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bldp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/min.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bracw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/atax.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sfe.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/reph.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kbr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/amrs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fmbi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sgza.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/oas.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mchx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/paa.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lvs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fdrr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/xoxo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sgbx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ldf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jhma.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bont.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rilyz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ffhl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/llnw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/evok.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bam.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aplp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nxp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/heq.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mfo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/emcf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tse.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/san_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cali.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vivo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/spun.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bcacu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rexr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/xrx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/msp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pcsb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hewu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/neo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/afsi_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vsec.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/eqt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aqn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pgr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sb_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/enr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pnc-ws.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wair.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aod.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/esgd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/igc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jout.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lnt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cik.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mlnt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/jhi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/smit.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ngvt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/trs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ahl_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/chk_d.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dd_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fox.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ftxo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/brg_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tmusp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bwp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rmni.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pffd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hlx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mnk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/plm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fnteu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ocfc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dynt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ago_e.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pcg_d.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/geh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aaww.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kirk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nee.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kool.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/snhy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sce_c.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aeg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/smci.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gluu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/out.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/axl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/oxy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/axas.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/csra.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cabo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pxus.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fmsa.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hds.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/airg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hrtx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ahgp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/moxc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/stra.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hcci.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ago_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fgp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tvpt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/scac.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mat.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/efc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pkd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ptie.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/utsl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/xmx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rso.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hewp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aks.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fsv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tess.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/evri.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lovw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/goodp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/glad.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/grow.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kref.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nesr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sui_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fnhc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/svvc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pdlb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sva.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/py.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/psb_x.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/urbn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wbif.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/box.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dmri.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/holx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ntp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bac-ws-b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nvr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cveo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/avhi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/eryp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sncr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/lope.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/glog_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cvx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/arwr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/vbfc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/sld.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/avd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/amrb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/imax.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/brg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tcs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/omfl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cers.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/edu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ssni.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/simo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/bml_h.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/riot.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dmrl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/hci.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nxeo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/txrh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dfs_b.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/calx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mer_p.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/regn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/eos.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/acxm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/alt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ifon.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/anda.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/len.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tgp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kang.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ytra.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/kpti.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pnbk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/clyh.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/putw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/plg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tds.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/grfs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/whr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/cvgi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/dx_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ddbi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rave.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/nano.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gnk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tax.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/emxc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aubn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/pxlw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/oran.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/fisi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/arkw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mkc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gblil.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/aker.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/ntes.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mgcd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/wtm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/mdvx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/glpi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/navb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/agn_a.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/gbil.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/amtd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/msf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/rnsc.us.txt
# ...
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pzd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/prb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pbp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/xrlv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/bdcs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/udn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/tipz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ihf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/iqdf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ctnn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/kbe.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/hgi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/hewj.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pff.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/wood.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/sij.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/jpnl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ipo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/blv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/iye.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/effe.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fad.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gaz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fud.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/jjt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/hyld.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/efav.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pey.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/tna.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/kold.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/chix.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/kfyp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/cnda.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/cntr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/syld.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ixp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/viov.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/dyy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/figy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/rtm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/axjl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/rwm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fmf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/corn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ibdp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/bil.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gdxx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/upw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fmy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/shyd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/aadr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/smdv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fhk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/choc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ldur.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ioil.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/mgv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/eqal.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/voe.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/dnl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/mzz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/drip.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/emcg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/qls.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/eden.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/agf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/hymb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fpl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/iscf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/hezu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/mgc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pex.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/inkm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/slv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/eelv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/dgt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/zmlp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/mdy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ziv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ewl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fcg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/sagg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/paf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/cafe.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/drv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/uym.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fmb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/sivr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/spyb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/itot.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/dwm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/rez.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gdx.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/cyb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/voog.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gal.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gres.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/jjc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/dvhl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/iyc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/cqqq.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/phb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/eev.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/braq.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/eurl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fif.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gsg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/unl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/soil.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/scin.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/sso.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/drn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gyld.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ibcc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/voo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/sgol.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/usfr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/vaw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/urth.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/adre.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pbd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/lmbs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/schz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/aaxj.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/xrt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/don.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/edv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/vnm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/rwo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/faz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/xlb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/jkj.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/dls.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/agz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ciu.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/vonv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/cape.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/dxjc.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pgm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pbw.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/xar.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/qtec.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ghii.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/jkf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/foil.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/iusb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ibmg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/imlp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/xlg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/vong.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/qat.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pfm.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/axjv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/hynd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/skf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gxg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fmk.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/math.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/xle.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/rxl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/hyzd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ewp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/bsjj.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/cvy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ftlb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/efo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ijr.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/eem.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pcy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fltb.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ite.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/plnd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/rcd.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gush.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/igih.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/dew.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/kce.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/acwv.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ltpz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/olo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/jjs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pzi.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ymlp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/iyz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/qdyn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/sea.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/tdtf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ald.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ule.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/tolz.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/nib.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/cefl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/vclt.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/flrn.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ieo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/dgp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/tan.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/byld.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/hdg.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pjp.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/prf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/iyy.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ewzs.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/retl.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/doo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fnde.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/xlf.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/euo.us.txt
# /kaggle/input/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/gcc.us.txt

# %% [markdown]
# <a id ='1' ></a>
# <h2 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">Load and Check Data 🗸 </h2>

# %%
data = pd.read_csv("/kaggle/input/price-volume-data-for-all-us-stocks-etfs/Stocks/tsla.us.txt")

# %%
#Let's examine a few examples from our data.
data.head()
# Out:
#          Date   Open   High    Low  Close    Volume  OpenInt
# 0  2010-06-28  17.00  17.00  17.00  17.00         0        0
# 1  2010-06-29  19.00  25.00  17.54  23.89  18783276        0
# 2  2010-06-30  25.79  30.42  23.30  23.83  17194394        0
# 3  2010-07-01  25.00  25.92  20.27  21.96   8229863        0
# 4  2010-07-02  23.00  23.10  18.71  19.20   5141807        0

# %%
print("Data Shape -->", data.shape)
# Out:
# Data Shape --> (1858, 7)

# %%
data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1858.000000  1858.000000  1858.000000  1858.000000  1.858000e+03
# mean    150.389741   152.898737   147.688064   150.355047  4.416508e+06
# std     107.071675   108.490099   105.481665   107.023737  4.244294e+06
# min      16.140000    16.630000     8.030000    15.800000  0.000000e+00
# 25%      31.002500    31.732500    30.285000    31.112500  1.283324e+06
# 50%     184.440000   188.660000   181.450000   184.850000  3.421026e+06
# 75%     231.477500   235.375000   227.772500   230.920000  5.917672e+06
# max     386.690000   389.610000   379.345000   385.000000  3.714989e+07
#
#        OpenInt
# count   1858.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
print("Do you have a null column? \n", data.isna().sum())
# Out:
# Do you have a null column?
#  Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64

# %% [markdown]
# <a id ='2' ></a>
# <h2 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">Recurrent Neural Networks (RNN) 📚</h2>
#
# ![RNN.png](attachment:ada57eb7-1b82-4065-aa82-1df2a2f4484c.png)

# %% [markdown]
# <a id ='3' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">What is this RNN ❓</h3>
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > RNN is a type of Deep Learning structure that is often used to predict the next step. So what is the biggest difference from other learning structures? The biggest difference from other deep learning structures is that they remember. Yes, RNNs can remember. </p>
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > Another difference is that in other neural networks, each input is independent from each other, while in RNNs the inputs are related to each other. How so ? RNN establishes relationships between inputs in order to follow the next step. It realizes education based on these relationships. </p>
#
# <a id ='4' ></a>
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > We said RNN will remember. so how does that happen? </p>
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > RNNs use a loop-like structure that rotates within themselves so that the relationships they have established are permanent. To understand this, let's look at the visual of the RNN structure. </p>
#
# ![RNNFirst.png](attachment:c19d8a3a-b019-4e7f-b607-d7df3510ff92.png)
#
# <ul>
#   <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > Let's examine the picture above, there are actually nodes in the hidden layer here. We can see this from the previous picture. </li>
#   <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > these nodes have temporal cycles that feed them. Thanks to this loop, even if an output is given, the input value is not forgotten and is kept in their memory. (Short memory) </li>
# </ul>
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > To understand this better, let's open this picture a little more. </p>
#
# ![RNNEX.png](attachment:7d78dcb1-9760-4aea-aa24-68e8f6755f88.png)
#
# <ul>
#   <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > As we understand from the picture. For example, y0 obtained in the previous step and x1, our current input, are used to output y1. </li>
# </ul>

# %% [markdown]
# <a id ='5' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">Why Recurrent Neural Networks ❓  </h3>
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > In the picture above we have seen the forward neural network. forward neural network : </p>
#
# <ul>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" >Cannot handle sequential data</li>
#         <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" >Takes into account the current entry.</li>
#         <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" >It does not consider previous entries, so it does not remember</li>
# </ul>
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > The solution to these problems is RNN. RNN can process sequential data, accept existing input data and previously received inputs.RNNs can remember previous entries as they have internal memories. </p>

# %% [markdown]
# <a id ='6' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">What are the application areas of RNN ❓  </h3>
#
# <ul>
#     <li style = "color:darkred" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > Image Captioning </p> </li>
#         <li style = "color:darkred" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > Time Series Prediction </p> </li>
#         <li style = "color:darkred" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > Natural Language Processing </p> </li>
#             <li style = "color:darkred" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > Machine Translation </p> </li>
# </ul>

# %% [markdown]
# <a id ='7' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">What are the types of RNN ❓  </h3>
#
# <ol>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > One to One </p> </li>
#         <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > One to Many </p> </li>
#         <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > Many to One </p> </li>
#             <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > Many to Many </p> </li>
# </ol>

# %% [markdown]
# <a id ='8' ></a>
# <h4 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold"> One to One ⁉️  </h4>
#
# ![RNNEX.png](attachment:b3836f81-4faa-4c65-b922-8f88da75da70.png)
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > This type of neural network can be called the vanilla neural network. It has a single entrance and a single exit. It is often used for machine learning problems. </p>

# %% [markdown]
# <a id ='9' ></a>
# <h4 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold"> One to Many ⁉️  </h4>
#
# ![OnetoMany.png](attachment:78913137-2b2c-48de-a6c8-248348238b10.png)
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > this neural network has one input and multiple outputs.  </p>
#
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > Example : An example is the picture and the sentence that describes it. A picture is input as input and a sentence describing it comes out. </p>

# %% [markdown]
# <a id ='10' ></a>
# <h4 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold"> Many to One ⁉️  </h4>
#
# ![manytoone.png](attachment:ea318661-d352-4401-a8ba-ecdf2dd6ca1b.png)
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > This RNN takes multiple inputs and yields a single output.  </p>
#
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > Example : Suppose it takes a sentence as input. It can also give the emotion of this sentence as output. as in the picture above. </p>

# %% [markdown]
# <a id ='11' ></a>
# <h4 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold"> Many to Many ⁉️  </h4>
#
# ![manytomany.png](attachment:84edcfa2-e8d1-443b-b996-9694f8f2d7d8.png)
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > It is a type of RNN that gives many inputs and many outputs.  </p>
#
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > Example : An example is machine translation from one language to another. </p>

# %% [markdown]
# <a id ='12' ></a>
# <h2 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Data Preprocessing ❔</h2>
#
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold"> In this section, we will make the data available for RNN. </p>
# <ul>
#      <li style = "color:black;font-family:Segoe Print;font-weight:bold" >Split the data as train and test</li>
#      <li style = "color:black;font-family:Segoe Print;font-weight:bold" >Normalize data.</li>
#      <li style = "color:black;font-family:Segoe Print;font-weight:bold" >X_train - y_train ?</li>
#     <li style = "color:black;font-family:Segoe Print;font-weight:bold" >Reshape</li>
# </ul>

# %% [markdown]
# <a id ='13' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Split the data as train and test ❓</h3>
#
# <ul>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >In this section, we will separate the data we have as a train and test. </p> </li>
# </ul>

# %%
training_size = int(len(data)*0.80)
data_len = len(data)

train, test = data[0:training_size],data[training_size:data_len]

# %%
print("Training Size --> ", training_size)
print("total length of data --> ", data_len)
print("Train length --> ", len(train))
print("Test length --> ", len(test))
# Out:
# Training Size -->  1486
# total length of data -->  1858
# Train length -->  1486
# Test length -->  372

# %% [markdown]
# <a id ='14' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Normalize data ❓</h3>
#
# <ul>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >In this section, we will normalize the data we have.</p> </li>
# </ul>
#
# <a id ='15' ></a>
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > Why do we normalize data? </p>
#
# <ul>
#         <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >Normalization is very important in all deep learning in general. </p> </li>
#             <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >Normalization makes the properties more consistent. This allows the model to predict its output more accurately.</p> </li>
#                 <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >In this notebook, since we use the "open" feature from our data to train the model, it will be sufficient to normalize it.</p> </li>
# </ul>

# %%
# the part of data that we will use as training.
train = train.loc[:, ["Open"]].values

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train)

# %% [markdown]
# <a id ='16' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > X_train - y_train ❓</h3>
#
# <ul>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >We will separate the normalized data into x_train and y_train. </p> </li>
#         <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >We will make this distinction 40 steps 40 steps. So we will train in 40 steps. We will anticipate step 41.didn't we understand Let's examine the picture below and visualize this in our minds. </p> </li>
# </ul>
#
# <a id ='17' ></a>
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > What is the steps logic? </p>
#
# ![Steps.png](attachment:f039f066-9cc8-4f01-98ad-8b672763020e.png)
#
# <ul>
#     <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >Let's think of the number of steps as 3, not 40. </p> </li>
#      <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >then we reserve the first 3 numbers for training data since our step count is 3. </p> </li>
#          <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >We try to guess the number that comes after these 3 numbers. so we separate it as y_train. </p> </li>
#              <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >And take this one step further, as you can see in the picture, we continue to do this. You can think of it exactly like this in our real data. </p> </li>
# </ul>

# %%
end_len = len(train_scaled)
X_train = []
y_train = []
timesteps = 40

for i in range(timesteps, end_len):
    X_train.append(train_scaled[i - timesteps:i, 0])
    y_train.append(train_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# <a id ='18' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Reshape ❓</h3>
#
# <a id ='19' ></a>
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > why do we reshape ?  </p>
#
# <ul>
#     <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > One of the most basic points to be considered in RNNs is that they want their input to have 3 dimensions. </p> </li>
#      <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >These 3 sizes are typically:</p> <ul>
#          <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" >the size of data we have</li>
#          <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" >Number of steps</li>
#          <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" >Number of features</li>
#          </ul> </li>
# </ul>

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print("X_train --> ", X_train.shape)
print("y_train shape --> ", y_train.shape)
# Out:
# X_train -->  (1446, 40, 1)
# y_train shape -->  (1446,)

# %% [markdown]
# <a id ='20' ></a>
# <h2 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold">Implementing with Keras ❔ </h2>
#
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold"> In this section, we create and fit  RNN model. </p>
# <ul>
#     <li style = "color:black;font-family:Segoe Print;font-weight:bold" >Create Model</li>
#     <li style = "color:black;font-family:Segoe Print;font-weight:bold" >Compile Model</li>
#     <li style = "color:black;font-family:Segoe Print;font-weight:bold" >Epochs and Batch Size</li>
#     <li style = "color:black;font-family:Segoe Print;font-weight:bold" >Fit the model</li>
# </ul>

# %% [markdown]
# <a id ='21' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Create Model❓</h3>
#
# <ul>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >We are importing the libraries we will use for our model.</p> </li>
#         <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >Later, we will create our RNN model.</p> </li>
# </ul>

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# %% [markdown]
# <ul>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >units --> Positive integer, dimensionality of the output space.</p> </li>
#         <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >activation --> Activation function to use. Default: hyperbolic tangent (tanh). If you pass None, no activation is applied (ie. "linear" activation: a(x) = x).</p> </li>
#             <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >return_sequences --> Boolean. Whether to return the last output in the output sequence, or the full sequence. Default: False.</p> </li>
#                 <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >inputs --> A 3D tensor, with shape [batch, timesteps, feature].</p> </li>
# </ul>
#
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > for detail referance --> <a href = "https://keras.io/api/layers/recurrent_layers/simple_rnn/" >https://keras.io/api/layers/recurrent_layers/simple_rnn/ </a> </p>

# %%
regressor = Sequential()

regressor.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True, input_shape = (X_train.shape[1],1)))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

# %% [markdown]
# <a id ='22' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Compile Model❓</h3>
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" > Yes, now we need to compile our model.  </p>
#
# <ul>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" >optimizer --> The optimizer does the process of updating our parameters for us here. some kind of healer I can say. There are methods used for multiple optimizers, and you should choose the most suitable one for the model. </li>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" >loss --> It is a number that indicates how good or bad the model is to its prediction. As it approaches 0, the error starts to decrease.</li>
# </ul>

# %%
regressor.compile(optimizer= "adam", loss = "mean_squared_error")

# %% [markdown]
# <a id ='23' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Epochs and Batch Size ❓</h3>
#
# <ul>
#     <li style = "color:black;font-family:Segoe Print;font-weight:bold" >Epochs : the forward and backward processing of data one by one. In other words, we can simply call it a complete educational tour. Education is determined by the number of eras. </li>
#         <li style = "color:black;font-family:Segoe Print;font-weight:bold" >Batch Size : Basically, in the periods I mentioned above, it takes a long time for us to train the data one by one. During training
# how much of the data,indicates that it will be trained. </li>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" >To give an example of this, imagine we have 10 loaves of bread. If we select batch_size as 2, imagine that we eat these breads 2 times and 2 times.</li>
# </ul>

# %%
epochs = 100 
batch_size = 20

# %% [markdown]
# <a id ='24' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Fit the model ❓</h3>
#
# <ul>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >We train the model we created above using our data. </p> </li>
# </ul>

# %%
regressor.fit(X_train, y_train, epochs = epochs, batch_size = batch_size)
# Out:
# Epoch 1/100
# 73/73 [==============================] - 5s 31ms/step - loss: 0.3634
# Epoch 2/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.1763
# Epoch 3/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0919
# Epoch 4/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0612
# Epoch 5/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0433
# Epoch 6/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0307
# Epoch 7/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0307
# Epoch 8/100
# 73/73 [==============================] - 2s 33ms/step - loss: 0.0297
# Epoch 9/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0196
# Epoch 10/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0173
# Epoch 11/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0164
# Epoch 12/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0145
# Epoch 13/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0131
# Epoch 14/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0132
# Epoch 15/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0110
# Epoch 16/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0102
# Epoch 17/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0110
# Epoch 18/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0092
# Epoch 19/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0073
# Epoch 20/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0084
# Epoch 21/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0069
# Epoch 22/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0075
# Epoch 23/100
# 73/73 [==============================] - 2s 34ms/step - loss: 0.0067
# Epoch 24/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0057
# Epoch 25/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0060
# Epoch 26/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0055
# Epoch 27/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0054
# Epoch 28/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0046
# Epoch 29/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0055
# Epoch 30/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0045
# Epoch 31/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0046
# Epoch 32/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0046
# Epoch 33/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0044
# Epoch 34/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0044
# Epoch 35/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0046
# Epoch 36/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0042
# Epoch 37/100
# 73/73 [==============================] - 2s 33ms/step - loss: 0.0037
# Epoch 38/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0037
# Epoch 39/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0033
# Epoch 40/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0026
# Epoch 41/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0029
# Epoch 42/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0031
# Epoch 43/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0031
# Epoch 44/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0028
# Epoch 45/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0032
# Epoch 46/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0032
# Epoch 47/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0027
# Epoch 48/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0029
# Epoch 49/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0027
# Epoch 50/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0032
# Epoch 51/100
# 73/73 [==============================] - 3s 34ms/step - loss: 0.0030
# Epoch 52/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0029
# Epoch 53/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0025
# Epoch 54/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0032
# Epoch 55/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0031
# Epoch 56/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0026
# Epoch 57/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0036
# Epoch 58/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0023
# Epoch 59/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0025
# Epoch 60/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0025
# Epoch 61/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0021
# Epoch 62/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0028
# Epoch 63/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0024
# Epoch 64/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0022
# Epoch 65/100
# 73/73 [==============================] - 2s 33ms/step - loss: 0.0023
# Epoch 66/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0020
# Epoch 67/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0023
# Epoch 68/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0020
# Epoch 69/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0025
# Epoch 70/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0020
# Epoch 71/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0031
# Epoch 72/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0022
# Epoch 73/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0023
# Epoch 74/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0019
# Epoch 75/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0021
# Epoch 76/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0019
# Epoch 77/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0020
# Epoch 78/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0021
# Epoch 79/100
# 73/73 [==============================] - 2s 33ms/step - loss: 0.0024
# Epoch 80/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0020
# Epoch 81/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0020
# Epoch 82/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0020
# Epoch 83/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0020
# Epoch 84/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0020
# Epoch 85/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0021
# Epoch 86/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0017
# Epoch 87/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0018
# Epoch 88/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0023
# Epoch 89/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0021
# Epoch 90/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0020
# Epoch 91/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0018
# Epoch 92/100
# 73/73 [==============================] - 2s 33ms/step - loss: 0.0017
# Epoch 93/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0019
# Epoch 94/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0017
# Epoch 95/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0020
# Epoch 96/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0017
# Epoch 97/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0018
# Epoch 98/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0014
# Epoch 99/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0018
# Epoch 100/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0017

# %% [markdown]
# <a id ='25' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Predict ❓</h3>
#
# <ul>
#     <li style = "color:darkred;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >We will make predictions using the model we have created.</p> </li>
# </ul>

# %%
test.head()
# Out:
#             Date    Open    High     Low   Close   Volume  OpenInt
# 1486  2016-05-24  216.60  218.74  215.18  217.91  2928659        0
# 1487  2016-05-25  217.91  221.36  216.51  219.58  2514028        0
# 1488  2016-05-26  220.50  225.26  219.05  225.12  3560997        0
# 1489  2016-05-27  224.99  225.93  220.75  223.04  3081734        0
# 1490  2016-05-31  223.04  224.75  221.50  223.23  2046828        0

# %% [markdown]
# <ul>
#     <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" > We use the data we separated above as our test data. </p> </li>
# </ul>

# %%
real_price = test.loc[:, ["Open"]].values
print("Real Price Shape --> ", real_price.shape)
# Out:
# Real Price Shape -->  (372, 1)

# %% [markdown]
# <ul>
#     <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >Since we use the "open" feature while training the model, we will use the same feature while testing. </p> </li>
# </ul>

# %%
dataset_total = pd.concat((data["Open"], test["Open"]), axis = 0)
inputs = dataset_total[len(dataset_total) - len(test) - timesteps:].values.reshape(-1,1)
inputs = scaler.transform(inputs)

# %% [markdown]
# <ul>
#     <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >we distinguish the values ​​that I will guess. </p> </li>
# </ul>

# %%
X_test = []

for i in range(timesteps, 412):
    X_test.append(inputs[i-timesteps:i, 0])
X_test = np.array(X_test)

print("X_test shape --> ", X_test.shape)
# Out:
# X_test shape -->  (372, 40)

# %% [markdown]
# <ul>
#     <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >Finally, we trained our model according to the steps above. We generate our test data based on this number of steps. </p> </li>
# </ul>

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predict = regressor.predict(X_test)
predict = scaler.inverse_transform(predict)

# %% [markdown]
# <ul>
#     <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >We can now make an estimate here as data is ready to predict. </p> </li>
#         <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >inverse_transform --> If you remember before training our model, we normalized our data. converts these values ​​to before normalization. </p> </li>
# </ul>

# %% [markdown]
# <a id ='26' ></a>
# <h3 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold" > Evaluate the model ❔</h3>
#
# <ul>
#     <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >yes, finally let's take a look at our results by comparing our predictions with real data. </p> </li>
# </ul>

# %%
plt.plot(real_price, color = "red", label = "Real Stock Price")
plt.plot(predict, color = "black", label = "Predict Stock Price")
plt.title("Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("Tesla Stock Price")
plt.legend()
plt.show()

# %% [markdown]
# <ul>
#     <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >Our model has made good predictions until a certain time, but after a while the difference with the real data has started to increase. </p> </li>
#      <li style = "color:darkblue;font-family:Segoe Print;font-weight:bold" > <p style = "color:black;font-family:Segoe Print;font-weight:bold" >Well, if we used LSTM instead of RNN, how would the result change? I will discuss this in my next notebook. </p> </li>
# </ul>

# %% [markdown]
# <a id ='27' ></a>
# <h4 style = "background:#0C0C0C ;color:white;border:0;font-family:Segoe Print;font-weight:bold"> CONCLUSION</h4>
#
# <p style = "color:darkred;font-family:Segoe Print;font-weight:bold" > I tried to talk more about the logic of the work without getting into mathematics. I hope I was able to help a little bit.I am waiting for them if you have any questions or suggestions. </p>
#
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" >  Seaborn Tutorial -->
#     <a href = "https://www.kaggle.com/rafetcan/visualization-tutorial-with-seaborn" >https://www.kaggle.com/rafetcan/visualization-tutorial-with-seaborn</a>
# </p>
# <p style = "color:black;font-family:Segoe Print;font-weight:bold" >  Plotly Tutorial -->
#     <a href = "https://www.kaggle.com/rafetcan/plotly-tutorial-for-beginners" >https://www.kaggle.com/rafetcan/plotly-tutorial-for-beginners</a>
#     <p style = "color:black;font-family:Segoe Print;font-weight:bold" >  CNN Tutorial -->
#     <a href = "https://www.kaggle.com/rafetcan/convolutional-neural-network-cnn-tutorial" >https://www.kaggle.com/rafetcan/convolutional-neural-network-cnn-tutorial</a>
# </p>
#
# <p style = "text-shadow: 12px 12px 2px #333;color:darkred;font-family:Segoe Print;font-weight:bold" > THANK YOU</p>
